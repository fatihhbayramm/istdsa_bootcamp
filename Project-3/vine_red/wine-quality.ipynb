# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from termcolor import colored

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

print(colored('\nAll libraries imported succesfully.', 'yellow'))
# Out:
# All libraries imported succesfully.

# %%
pd.options.mode.copy_on_write = True # Allow re-write on variable
sns.set_style('darkgrid') # Seaborn style
warnings.filterwarnings('ignore') # Ignore warnings
pd.set_option('display.max_columns', None) # Setting this option will print all collumns of a dataframe
pd.set_option('display.max_colwidth', None) # Setting this option will print all of the data in a feature

# %%
sns.color_palette("cool_r", n_colors=1)
# Out:
# [(0.4980392156862745, 0.5019607843137255, 1.0)]

# %%
sns.set_palette("cool_r")
print(colored('\nAll libraries Configed succesfully.', 'yellow'))
# Out:
# All libraries Configed succesfully.

# %%
# Importing the dataset
df=pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe().T.style.background_gradient(cmap='Purples', axis=0)
# Out:
# <style type="text/css">
# #T_023d6_row0_col0, #T_023d6_row1_col0, #T_023d6_row1_col2, #T_023d6_row1_col7, #T_023d6_row2_col0, #T_023d6_row2_col1, #T_023d6_row2_col2, #T_023d6_row2_col3, #T_023d6_row2_col4, #T_023d6_row2_col5, #T_023d6_row2_col6, #T_023d6_row2_col7, #T_023d6_row3_col0, #T_023d6_row4_col0, #T_023d6_row4_col1, #T_023d6_row4_col2, #T_023d6_row4_col3, #T_023d6_row4_col4, #T_023d6_row4_col5, #T_023d6_row4_col6, #T_023d6_row4_col7, #T_023d6_row5_col0, #T_023d6_row6_col0, #T_023d6_row7_col0, #T_023d6_row7_col2, #T_023d6_row7_col7, #T_023d6_row8_col0, #T_023d6_row8_col2, #T_023d6_row9_col0, #T_023d6_row9_col2, #T_023d6_row9_col7, #T_023d6_row10_col0, #T_023d6_row11_col0 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_023d6_row0_col1, #T_023d6_row10_col6 {
#   background-color: #e6e5f1;
#   color: #000000;
# }
# #T_023d6_row0_col2, #T_023d6_row0_col7, #T_023d6_row3_col1, #T_023d6_row3_col7, #T_023d6_row8_col6 {
#   background-color: #f7f5fa;
#   color: #000000;
# }
# #T_023d6_row0_col3 {
#   background-color: #928fc3;
#   color: #f1f1f1;
# }
# #T_023d6_row0_col4 {
#   background-color: #c9c9e2;
#   color: #000000;
# }
# #T_023d6_row0_col5 {
#   background-color: #e2e1ef;
#   color: #000000;
# }
# #T_023d6_row0_col6 {
#   background-color: #eceaf3;
#   color: #000000;
# }
# #T_023d6_row1_col1, #T_023d6_row1_col3, #T_023d6_row1_col4, #T_023d6_row1_col5, #T_023d6_row1_col6, #T_023d6_row7_col6, #T_023d6_row8_col7, #T_023d6_row9_col1, #T_023d6_row9_col5, #T_023d6_row9_col6 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_023d6_row3_col2, #T_023d6_row3_col6, #T_023d6_row7_col4, #T_023d6_row9_col3 {
#   background-color: #f8f7fa;
#   color: #000000;
# }
# #T_023d6_row3_col3 {
#   background-color: #f1eff6;
#   color: #000000;
# }
# #T_023d6_row3_col4, #T_023d6_row8_col5 {
#   background-color: #f3f2f8;
#   color: #000000;
# }
# #T_023d6_row3_col5 {
#   background-color: #f6f5f9;
#   color: #000000;
# }
# #T_023d6_row5_col1 {
#   background-color: #c4c5e0;
#   color: #000000;
# }
# #T_023d6_row5_col2 {
#   background-color: #cacae3;
#   color: #000000;
# }
# #T_023d6_row5_col3, #T_023d6_row7_col3, #T_023d6_row11_col1 {
#   background-color: #f0eef5;
#   color: #000000;
# }
# #T_023d6_row5_col4 {
#   background-color: #cbcbe3;
#   color: #000000;
# }
# #T_023d6_row5_col5 {
#   background-color: #bebfdd;
#   color: #000000;
# }
# #T_023d6_row5_col6 {
#   background-color: #c5c6e1;
#   color: #000000;
# }
# #T_023d6_row5_col7 {
#   background-color: #dadaeb;
#   color: #000000;
# }
# #T_023d6_row6_col1, #T_023d6_row6_col2, #T_023d6_row6_col4, #T_023d6_row6_col5, #T_023d6_row6_col6, #T_023d6_row6_col7, #T_023d6_row10_col3 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_023d6_row6_col3 {
#   background-color: #705eaa;
#   color: #f1f1f1;
# }
# #T_023d6_row7_col1, #T_023d6_row9_col4 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_023d6_row7_col5, #T_023d6_row11_col2, #T_023d6_row11_col7 {
#   background-color: #faf8fb;
#   color: #000000;
# }
# #T_023d6_row8_col1 {
#   background-color: #f5f4f9;
#   color: #000000;
# }
# #T_023d6_row8_col3 {
#   background-color: #c8c8e2;
#   color: #000000;
# }
# #T_023d6_row8_col4 {
#   background-color: #ecebf4;
#   color: #000000;
# }
# #T_023d6_row10_col1, #T_023d6_row11_col4 {
#   background-color: #dedeed;
#   color: #000000;
# }
# #T_023d6_row10_col2 {
#   background-color: #f9f7fb;
#   color: #000000;
# }
# #T_023d6_row10_col4 {
#   background-color: #aeadd3;
#   color: #000000;
# }
# #T_023d6_row10_col5 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_023d6_row10_col7 {
#   background-color: #f7f6fa;
#   color: #000000;
# }
# #T_023d6_row11_col3 {
#   background-color: #c0c1de;
#   color: #000000;
# }
# #T_023d6_row11_col5 {
#   background-color: #eae9f3;
#   color: #000000;
# }
# #T_023d6_row11_col6 {
#   background-color: #f2f0f7;
#   color: #000000;
# }
# </style>
# <table id="T_023d6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_023d6_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_023d6_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_023d6_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_023d6_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_023d6_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_023d6_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_023d6_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_023d6_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_023d6_level0_row0" class="row_heading level0 row0" >fixed acidity</th>
#       <td id="T_023d6_row0_col0" class="data row0 col0" >1599.000000</td>
#       <td id="T_023d6_row0_col1" class="data row0 col1" >8.319637</td>
#       <td id="T_023d6_row0_col2" class="data row0 col2" >1.741096</td>
#       <td id="T_023d6_row0_col3" class="data row0 col3" >4.600000</td>
#       <td id="T_023d6_row0_col4" class="data row0 col4" >7.100000</td>
#       <td id="T_023d6_row0_col5" class="data row0 col5" >7.900000</td>
#       <td id="T_023d6_row0_col6" class="data row0 col6" >9.200000</td>
#       <td id="T_023d6_row0_col7" class="data row0 col7" >15.900000</td>
#     </tr>
#     <tr>
#       <th id="T_023d6_level0_row1" class="row_heading level0 row1" >volatile acidity</th>
#       <td id="T_023d6_row1_col0" class="data row1 col0" >1599.000000</td>
#       <td id="T_023d6_row1_col1" class="data row1 col1" >0.527821</td>
#       <td id="T_023d6_row1_col2" class="data row1 col2" >0.179060</td>
#       <td id="T_023d6_row1_col3" class="data row1 col3" >0.120000</td>
#       <td id="T_023d6_row1_col4" class="data row1 col4" >0.390000</td>
#       <td id="T_023d6_row1_col5" class="data row1 col5" >0.520000</td>
#       <td id="T_023d6_row1_col6" class="data row1 col6" >0.640000</td>
#       <td id="T_023d6_row1_col7" class="data row1 col7" >1.580000</td>
#     </tr>
#     <tr>
#       <th id="T_023d6_level0_row2" class="row_heading level0 row2" >citric acid</th>
#       <td id="T_023d6_row2_col0" class="data row2 col0" >1599.000000</td>
#       <td id="T_023d6_row2_col1" class="data row2 col1" >0.270976</td>
#       <td id="T_023d6_row2_col2" class="data row2 col2" >0.194801</td>
#       <td id="T_023d6_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_023d6_row2_col4" class="data row2 col4" >0.090000</td>
#       <td id="T_023d6_row2_col5" class="data row2 col5" >0.260000</td>
#       <td id="T_023d6_row2_col6" class="data row2 col6" >0.420000</td>
#       <td id="T_023d6_row2_col7" class="data row2 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_023d6_level0_row3" class="row_heading level0 row3" >residual sugar</th>
#       <td id="T_023d6_row3_col0" class="data row3 col0" >1599.000000</td>
#       <td id="T_023d6_row3_col1" class="data row3 col1" >2.538806</td>
#       <td id="T_023d6_row3_col2" class="data row3 col2" >1.409928</td>
#       <td id="T_023d6_row3_col3" class="data row3 col3" >0.900000</td>
#       <td id="T_023d6_row3_col4" class="data row3 col4" >1.900000</td>
#       <td id="T_023d6_row3_col5" class="data row3 col5" >2.200000</td>
#       <td id="T_023d6_row3_col6" class="data row3 col6" >2.600000</td>
#       <td id="T_023d6_row3_col7" class="data row3 col7" >15.500000</td>
#     </tr>
#     <tr>
#       <th id="T_023d6_level0_row4" class="row_heading level0 row4" >chlorides</th>
#       <td id="T_023d6_row4_col0" class="data row4 col0" >1599.000000</td>
#       <td id="T_023d6_row4_col1" class="data row4 col1" >0.087467</td>
#       <td id="T_023d6_row4_col2" class="data row4 col2" >0.047065</td>
#       <td id="T_023d6_row4_col3" class="data row4 col3" >0.012000</td>
#       <td id="T_023d6_row4_col4" class="data row4 col4" >0.070000</td>
#       <td id="T_023d6_row4_col5" class="data row4 col5" >0.079000</td>
#       <td id="T_023d6_row4_col6" class="data row4 col6" >0.090000</td>
#       <td id="T_023d6_row4_col7" class="data row4 col7" >0.611000</td>
#     </tr>
#     <tr>
#       <th id="T_023d6_level0_row5" class="row_heading level0 row5" >free sulfur dioxide</th>
#       <td id="T_023d6_row5_col0" class="data row5 col0" >1599.000000</td>
#       <td id="T_023d6_row5_col1" cla

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# volatile acidity            0.001918   0.061298            -0.010504
# citric acid                 0.143577   0.203823            -0.060978
# residual sugar              1.000000   0.055610             0.187049
# chlorides                   0.055610   1.000000             0.005562
# free sulfur dioxide         0.187049   0.005562             1.000000
# total sulfur dioxide        0.203028   0.047400             0.667666
# density                     0.355283   0.200632            -0.021946
# pH                         -0.085652  -0.265026             0.070377
# sulphates                   0.005527   0.371260             0.051658
# alcohol                     0.042075  -0.221141            -0.069408
# quality                     0.013732  -0.128907            -0.050656
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.113181  0.668047 -0.682978   0.183006
# volatile acidity                  0.076470  0.022026  0.234937  -0.260987
# citric acid                       0.035533  0.364947 -0.541904   0.312770
# residual sugar                    0.203028  0.355283 -0.085652   0.005527
# chlorides                         0.047400  0.200632 -0.265026   0.371260
# free sulfur dioxide               0.667666 -0.021946  0.070377   0.051658
# total sulfur dioxide              1.000000  0.071269 -0.066495   0.042947
# density                           0.071269  1.000000 -0.341699   0.148506
# pH                               -0.066495 -0.341699  1.000000  -0.196648
# sulphates                         0.042947  0.148506 -0.196648   1.000000
# alcohol                          -0.205654 -0.496180  0.205633   0.093595
# quality                          -0.185100 -0.174919 -0.057731   0.251397
#
#                        alcohol   quality
# fixed acidity        -0.061668  0.124052
# volatile acidity     -0.202288 -0.390558
# citric acid           0.109903  0.226373
# residual sugar        0.042075  0.013732
# chlorides            -0.221141 -0.128907
# free sulfur dioxide  -0.069408 -0.050656
# total sulfur dioxide -0.205654 -0.185100
# density              -0.496180 -0.174919
# pH                    0.205633 -0.057731
# sulphates             0.093595  0.251397
# alcohol               1.000000  0.476166
# quality               0.476166  1.000000

# %%
corr = df.corr()
# cmap = sns.diverging_palette(-1, 1, s=100, l=50, n=15, center="dark", as_cmap=True)
plt.figure(figsize=(9, 6))
sns.heatmap(corr, annot=True, fmt='.2f', linewidth=0.5, cmap='Purples', mask=np.triu(corr))
plt.show()
